# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv("loan.csv")

# %%
df=pd.read_csv("loan.csv")
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.describe()#1
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df[df.isna().any(axis=1)]#2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 16   LP001034    Male      No          1  Not Graduate            No
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 592  LP002933     NaN      No         3+      Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 601  LP002950    Male     Yes          0  Not Graduate           NaN
# 605  LP002960    Male     Yes          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.dropna(inplace=True)

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
x=df["ApplicantIncome"].to_numpy()#3
y=df["LoanAmount"].to_numpy()
df1=plt.scatter(x,y)
plt.title("relation visualization with scatter plot")
plt.xlabel("ApplicantIncome")
plt.ylabel("LoanAmount")
# Out:
# Text(0, 0.5, 'LoanAmount')

# %%
df.loc[:,"ApplicantIncome"].corr(df.loc[:,"LoanAmount"],method="pearson",min_periods=1)#4
# Out:
# 0.49530958608655357

# %%
boxplot=df.boxplot(column=["ApplicantIncome","LoanAmount"])

# %%
df.LoanAmount.unique()#5
# Out:
# array([128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70., 200.,
#        114.,  17., 125.,  76., 133., 104., 315., 116., 191., 122., 110.,
#         35.,  74., 106., 320., 144., 184.,  80.,  47., 134.,  44., 100.,
#        112., 286.,  97.,  96., 135., 180.,  99., 165., 258., 126., 312.,
#        136., 172.,  81., 187., 113., 176., 111., 167.,  50., 210., 175.,
#        131., 188.,  25., 137., 115., 151., 225., 216.,  94., 185., 154.,
#        259., 194., 160., 102., 290.,  84.,  88., 242., 129.,  30., 118.,
#        152., 244., 600., 255.,  98., 275., 121.,  75.,  63.,  87., 101.,
#        495.,  73., 260., 108.,  48., 164., 170.,  83.,  90., 166., 124.,
#         55.,  59., 127., 214., 240., 130.,  60., 280., 140., 155., 123.,
#        201., 138., 279., 192., 304., 150., 207., 436.,  78.,  54.,  89.,
#        139.,  93., 132., 480.,  56., 300., 376.,  67., 117.,  71., 173.,
#         46., 228., 308., 105., 236., 570., 380., 296., 156., 109., 103.,
# ...

# %%
data_crosstab=pd.crosstab(df['Loan_Status'],df['ApplicantIncome'])#6
print(data_crosstab)
# Out:
# ApplicantIncome  150    645    1000   1025   1299   1378   1442   1500   \
# Loan_Status
# N                    1      0      1      0      0      1      1      1
# Y                    0      1      0      1      1      0      0      0
#
# ApplicantIncome  1538   1600   ...  18165  18333  19484  19730  20233  33846  \
# Loan_Status                    ...
# N                    0      1  ...      0      1      0      1      1      1
# Y                    1      0  ...      1      0      1      0      0      0
#
# ApplicantIncome  37719  39147  39999  81000
# Loan_Status
# N                    0      0      0      1
# Y                    1      1      1      0
#
# [2 rows x 405 columns]

# %%
from scipy import stats
chi2, p, dof, expected = stats.chi2_contingency(data_crosstab)
print("chi-square statistics", chi2)
print("p-value:", p)
# Out:
# chi-square statistics 399.62785504954184
# p-value: 0.5520698883903832

# %%
df_row1=df.iloc[1:11, [4,9]]#7
df_row1.describe()
# Out:
#        Loan_Amount_Term
# count              10.0
# mean              360.0
# std                 0.0
# min               360.0
# 25%               360.0
# 50%               360.0
# 75%               360.0
# max               360.0

# %%
df=pd.read_csv("loan.csv")#8
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df=pd.get_dummies(df,columns=['Gender'],drop_first=True)
print(df.head())
# Out:
#     Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0  LP001002      No          0      Graduate            No             5849
# 1  LP001003     Yes          1      Graduate            No             4583
# 2  LP001005     Yes          0      Graduate           Yes             3000
# 3  LP001006     Yes          0  Not Graduate            No             2583
# 4  LP001008      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Gender_Male
# 0         Urban           Y            1
# ...

# %%
Loan_subset=df[['Gender_Male','ApplicantIncome']]
Loan_subset.head()
# Out:
#    Gender_Male  ApplicantIncome
# 0            1             5849
# 1            1             4583
# 2            1             3000
# 3            1             2583
# 4            1             6000

# %%
Loan_subset.describe()#9
# Out:
#        Gender_Male  ApplicantIncome
# count   614.000000       614.000000
# mean      0.796417      5403.459283
# std       0.402991      6109.041673
# min       0.000000       150.000000
# 25%       1.000000      2877.500000
# 50%       1.000000      3812.500000
# 75%       1.000000      5795.000000
# max       1.000000     81000.000000

# %%
df=pd.read_csv("loan.csv")
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df=pd.get_dummies(df,columns=['Married','Property_Area'],drop_first=True)

# %%
print(df.head())
# Out:
#   Gender  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0   Male             5849                0.0         NaN             360.0
# 1   Male             4583             1508.0       128.0             360.0
# 2   Male             3000                0.0        66.0             360.0
# 3   Male             2583             2358.0       120.0             360.0
# 4   Male             6000                0.0       141.0             360.0
#
#    Credit_History  Married_Yes  Property_Area_Semiurban  Property_Area_Urban  \
# 0             1.0            0                        0                    1
# 1             1.0            1                        0                    0
# 2             1.0            1                        0                    1
# 3             1.0            1                        0                    1
# 4             1.0            0                        0                    1
#
# ...

# %%
df=df.drop('Loan_ID',axis=1)

# %%
df=pd.get_dummies(df,columns=['Education','Loan_Status'],drop_first=True)

# %%
print(df)
# Out:
#      Gender Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0      Male          0            No             5849                0.0
# 1      Male          1            No             4583             1508.0
# 2      Male          0           Yes             3000                0.0
# 3      Male          0            No             2583             2358.0
# 4      Male          0            No             6000                0.0
# ..      ...        ...           ...              ...                ...
# 609  Female          0            No             2900                0.0
# 610    Male         3+            No             4106                0.0
# 611    Male          1            No             8072              240.0
# 612    Male          2            No             7583                0.0
# 613  Female          0           Yes             4583                0.0
#
#      LoanAmount  Loan_Amount_Term  Credit_History  Married_Yes  \
# ...

# %%
df=pd.get_dummies(df,columns=['Self_Employed'],drop_first=True)

# %%
print(df)
# Out:
#      Gender Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0      Male          0             5849                0.0         NaN
# 1      Male          1             4583             1508.0       128.0
# 2      Male          0             3000                0.0        66.0
# 3      Male          0             2583             2358.0       120.0
# 4      Male          0             6000                0.0       141.0
# ..      ...        ...              ...                ...         ...
# 609  Female          0             2900                0.0        71.0
# 610    Male         3+             4106                0.0        40.0
# 611    Male          1             8072              240.0       253.0
# 612    Male          2             7583                0.0       187.0
# 613  Female          0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  Married_Yes  Property_Area_Semiurban  \
# ...

# %%
df=df.drop('Dependents',axis=1)

# %%
print(df)
# Out:
#      Gender  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0      Male             5849                0.0         NaN             360.0
# 1      Male             4583             1508.0       128.0             360.0
# 2      Male             3000                0.0        66.0             360.0
# 3      Male             2583             2358.0       120.0             360.0
# 4      Male             6000                0.0       141.0             360.0
# ..      ...              ...                ...         ...               ...
# 609  Female             2900                0.0        71.0             360.0
# 610    Male             4106                0.0        40.0             180.0
# 611    Male             8072              240.0       253.0             360.0
# 612    Male             7583                0.0       187.0             360.0
# 613  Female             4583                0.0       133.0             360.0
#
# ...
